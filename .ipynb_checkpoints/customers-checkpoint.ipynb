# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv("customers (1).csv")

# %%
df
# Out:
#      customer_id  gender  age        city signup_date loyalty_member
# 0          C0001    Male   19   Liverpool  2023-10-17            Yes
# 1          C0002    Male   65  Manchester  2022-08-17            Yes
# 2          C0003  Female   20      London  2023-08-28            Yes
# 3          C0004    Male   50      London  2022-08-12            Yes
# 4          C0005  Female   32  Nottingham  2023-10-28             No
# ...          ...     ...  ...         ...         ...            ...
# 1195       C1196  Female   20      London  2023-02-25             No
# 1196       C1197    Male   55  Nottingham  2023-01-13            Yes
# 1197       C1198  Female   47  Manchester  2022-05-26            Yes
# 1198       C1199  Female   58  Manchester  2022-09-09             No
# 1199       C1200    Male   39      London  2023-09-20             No
#
# [1200 rows x 6 columns]

# %%
df.head()
# Out:
#   customer_id  gender  age        city signup_date loyalty_member
# 0       C0001    Male   19   Liverpool  2023-10-17            Yes
# 1       C0002    Male   65  Manchester  2022-08-17            Yes
# 2       C0003  Female   20      London  2023-08-28            Yes
# 3       C0004    Male   50      London  2022-08-12            Yes
# 4       C0005  Female   32  Nottingham  2023-10-28             No

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   customer_id     1200 non-null   str
#  1   gender          1200 non-null   str
#  2   age             1200 non-null   int64
#  3   city            1200 non-null   str
#  4   signup_date     1200 non-null   str
#  5   loyalty_member  1200 non-null   str
# dtypes: int64(1), str(5)
# memory usage: 56.4 KB

# %%
df.isnull().sum()
# Out:
# customer_id       0
# gender            0
# age               0
# city              0
# signup_date       0
# loyalty_member    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                age
# count  1200.000000
# mean     41.615833
# std      13.719515
# min      18.000000
# 25%      30.000000
# 50%      41.000000
# 75%      54.000000
# max      65.000000

# %%
df.shape
# Out:
# (1200, 6)

# %%
df.columns
# Out:
# Index(['customer_id', 'gender', 'age', 'city', 'signup_date',
#        'loyalty_member'],
#       dtype='str')

# %%
df.head()
# Out:
#   customer_id  gender  age        city signup_date loyalty_member
# 0       C0001    Male   19   Liverpool  2023-10-17            Yes
# 1       C0002    Male   65  Manchester  2022-08-17            Yes
# 2       C0003  Female   20      London  2023-08-28            Yes
# 3       C0004    Male   50      London  2022-08-12            Yes
# 4       C0005  Female   32  Nottingham  2023-10-28             No

# %%
sns.histplot(df["age"],kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.countplot(x=df["gender"])
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df["age"])
# Out:
# <Axes: xlabel='age'>

# %%
#laberl enUnicodeWarning
df["gender"]=df["gender"].replace({"Male":0,"Female":1})

# %%
df
# Out:
#      customer_id gender  age        city signup_date loyalty_member
# 0          C0001      0   19   Liverpool  2023-10-17            Yes
# 1          C0002      0   65  Manchester  2022-08-17            Yes
# 2          C0003      1   20      London  2023-08-28            Yes
# 3          C0004      0   50      London  2022-08-12            Yes
# 4          C0005      1   32  Nottingham  2023-10-28             No
# ...          ...    ...  ...         ...         ...            ...
# 1195       C1196      1   20      London  2023-02-25             No
# 1196       C1197      0   55  Nottingham  2023-01-13            Yes
# 1197       C1198      1   47  Manchester  2022-05-26            Yes
# 1198       C1199      1   58  Manchester  2022-09-09             No
# 1199       C1200      0   39      London  2023-09-20             No
#
# [1200 rows x 6 columns]

# %%
df["loyalty_member"]=df["loyalty_member"].replace({"Yes":0,"No":1})

# %%
df
# Out:
#      customer_id gender  age        city signup_date loyalty_member
# 0          C0001      0   19   Liverpool  2023-10-17              0
# 1          C0002      0   65  Manchester  2022-08-17              0
# 2          C0003      1   20      London  2023-08-28              0
# 3          C0004      0   50      London  2022-08-12              0
# 4          C0005      1   32  Nottingham  2023-10-28              1
# ...          ...    ...  ...         ...         ...            ...
# 1195       C1196      1   20      London  2023-02-25              1
# 1196       C1197      0   55  Nottingham  2023-01-13              0
# 1197       C1198      1   47  Manchester  2022-05-26              0
# 1198       C1199      1   58  Manchester  2022-09-09              1
# 1199       C1200      0   39      London  2023-09-20              1
#
# [1200 rows x 6 columns]

# %%
df["gender"].value_counts()
# Out:
# gender
# 0    613
# 1    587
# Name: count, dtype: int64

# %%
df["loyalty_member"].value_counts()
# Out:
# loyalty_member
# 1    630
# 0    570
# Name: count, dtype: int64

# %%
df["customer_id"].value_counts()
# Out:
# customer_id
# C0001    1
# C0002    1
# C0003    1
# C0004    1
# C0005    1
#         ..
# C1196    1
# C1197    1
# C1198    1
# C1199    1
# C1200    1
# Name: count, Length: 1200, dtype: int64
