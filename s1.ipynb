# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Student_Performance.csv")

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(127)

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df.columns
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Extracurricular Activities',
#        'Sleep Hours', 'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='str')

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
sns.histplot(df["Hours Studied"],kde=True)
# Out:
# <Axes: xlabel='Hours Studied', ylabel='Count'>

# %%
sns.histplot(df["Previous Scores"],kde=True)
# Out:
# <Axes: xlabel='Previous Scores', ylabel='Count'>

# %%
sns.histplot(df["Sleep Hours"],kde=True)
# Out:
# <Axes: xlabel='Sleep Hours', ylabel='Count'>

# %%
sns.histplot(df["Sample Question Papers Practiced"],kde=True)
# Out:
# <Axes: xlabel='Sample Question Papers Practiced', ylabel='Count'>

# %%
sns.countplot(x=df["Extracurricular Activities"])
# Out:
# <Axes: xlabel='Extracurricular Activities', ylabel='count'>

# %%
for col in df:
    print(df[col].value_counts())
# Out:
# Hours Studied
# 1    1152
# 6    1133
# 7    1129
# 3    1119
# 9    1115
# 5    1094
# 8    1088
# 4    1085
# 2    1085
# Name: count, dtype: int64
# Previous Scores
# 54    216
# 87    208
# 56    192
# 62    184
# 89    182
# 77    181
# 60    181
# 53    181
# 52    176
# 58    176
# 57    176
# 91    175
# 84    175
# 49    175
# 66    175
# 65    175
# 79    174
# 97    174
# 83    173
# 40    173
# 75    172
# 47    172
# 90    172
# 70    172
# 93    172
# 92    172
# 42    171
# 44    170
# 48    170
# 95    169
# 41    169
# 67    168
# 43    167
# 73    166
# 78    165
# 61    165
# 88    164
# 59    163
# 63    163
# 46    163
# 86    162
# 81    161
# 99    159
# 96    159
# 85    159
# 71    159
# 98    158
# 45    154
# 68    153
# 69    153
# 80    153
# 82    148
# 72    148
# 94    148
# 64    147
# 55    144
# 74    143
# 76    142
# 51    140
# 50    123
# Name: count, dtype: int64
# Extracurricular Activities
# No     5052
# Yes    4948
# ...

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
nc = ['Hours Studied','Previous Scores','Sleep Hours','Sample Question Papers Practiced','Performance Index']
for col in nc:
    plt.figure(figsize=(6,4))
    sns.boxplot(x=df[col])

# %%
df = pd.read_csv("Student_Performance.csv")
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.shape
# Out:
# (9873, 6)

# %%
df["Extracurricular Activities"]=df["Extracurricular Activities"].replace({"Yes":0,"No":1})

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                          0            9
# 1                 4               82                          1            4
# 2                 8               51                          0            7
# 3                 5               52                          0            5
# 4                 7               75                          1            8
# ...             ...              ...                        ...          ...
# 9995              1               49                          0            4
# 9996              7               64                          0            8
# 9997              6               83                          0            8
# 9998              9               97                          0            7
# 9999              7               74                          1            8
#
# ...

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 9873 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     9873 non-null   int64
#  1   Previous Scores                   9873 non-null   int64
#  2   Extracurricular Activities        9873 non-null   object
#  3   Sleep Hours                       9873 non-null   int64
#  4   Sample Question Papers Practiced  9873 non-null   int64
#  5   Performance Index                 9873 non-null   float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 539.9+ KB

# %%
from sklearn.preprocessing import StandardScaler
df2=["Previous Scores"]
scaler=StandardScaler()
df[df2]=scaler.fit_transform(df[df2])

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7         1.706168                          0            9
# 1                 4         0.724912                          1            4
# 2                 8        -1.064438                          0            7
# 3                 5        -1.006717                          0            5
# 4                 7         0.320865                          1            8
# ...             ...              ...                        ...          ...
# 9995              1        -1.179880                          0            4
# 9996              7        -0.314066                          0            8
# 9997              6         0.782633                          0            8
# 9998              9         1.590727                          0            7
# 9999              7         0.263144                          1            8
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
df3=["Hours Studied","Sleep Hours","Sample Question Papers Practiced"]
scaler=StandardScaler()
df[df3]=scaler.fit_transform(df[df3])

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0          0.775566         1.706168                          0     1.454025
# 1         -0.383205         0.724912                          1    -1.491315
# 2          1.161822        -1.064438                          0     0.275889
# 3          0.003052        -1.006717                          0    -0.902247
# 4          0.775566         0.320865                          1     0.864957
# ...             ...              ...                        ...          ...
# 9995      -1.541976        -1.179880                          0    -1.491315
# 9996       0.775566        -0.314066                          0     0.864957
# 9997       0.389309         0.782633                          0     0.864957
# 9998       1.548079         1.590727                          0     0.275889
# 9999       0.775566         0.263144                          1     0.864957
#
# ...
